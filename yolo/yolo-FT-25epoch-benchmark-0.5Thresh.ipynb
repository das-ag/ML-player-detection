# %%
import os
import torch
import torchvision.transforms as T
import matplotlib.pyplot as plt
from collections import defaultdict
from PIL import Image
from tqdm import tqdm
from ultralytics import YOLO  # Ensure you have `pip install ultralytics`
import random


# --- CONFIG ---
# DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {DEVICE}") 
BASE_DATA_ROOT = "../soccernet_data/tracking"
GT_FILENAME = "gt.txt"
IMAGE_FOLDER = "img1"
IMAGE_EXTS = ['.jpg', '.png']
NUM_VISUALS = 10
SCORE_THRESH = 0.5
IOU_THRESH = 0.5
SAMPLE_PER_SEQ = 30
# Out:
# Using device: mps

# %%
# --- LOAD MODEL ---
model = YOLO("discovery-runs/detect/ft-25epoch/weights/best.pt").to(DEVICE)


transform = T.ToTensor()

def load_gt_boxes(gt_path):
    gt_dict = defaultdict(list)
    if not os.path.exists(gt_path):
        return gt_dict
    with open(gt_path, 'r') as f:
        for line in f:
            parts = line.strip().split(',')
            frame, _, x, y, w, h, cls, _, _ = map(int, parts[:9])
            gt_dict[frame].append(torch.tensor([x, y, x + w, y + h], device=DEVICE))
    return gt_dict

def compute_iou(box1, box2):
    if box1.size(0) == 0 or box2.size(0) == 0:
        return torch.zeros((box1.size(0), box2.size(0)), device=box1.device)
    area1 = (box1[:, 2] - box1[:, 0]) * (box1[:, 3] - box1[:, 1])
    area2 = (box2[:, 2] - box2[:, 0]) * (box2[:, 3] - box2[:, 1])
    lt = torch.max(box1[:, None, :2], box2[:, :2])
    rb = torch.min(box1[:, None, 2:], box2[:, 2:])
    wh = (rb - lt).clamp(min=0)
    inter = wh[:, :, 0] * wh[:, :, 1]
    union = area1[:, None] + area2 - inter
    iou = inter / union
    return iou

def plot_gt_and_detections(image_tensor, detections, gt_boxes):
    from torchvision.utils import draw_bounding_boxes
    all_boxes = []
    labels = []
    colors = []

    for box in detections:
        all_boxes.append(box)
        labels.append("pred")
        colors.append("red")

    for box in gt_boxes:
        all_boxes.append(box)
        labels.append("gt")
        colors.append("green")

    if not all_boxes:
        return T.ToPILImage()(image_tensor)
    
    boxes_tensor = torch.stack(all_boxes).cpu()

    
    x1 = torch.min(boxes_tensor[:, 0], boxes_tensor[:, 2])
    y1 = torch.min(boxes_tensor[:, 1], boxes_tensor[:, 3])
    x2 = torch.max(boxes_tensor[:, 0], boxes_tensor[:, 2])
    y2 = torch.max(boxes_tensor[:, 1], boxes_tensor[:, 3])
    boxes_tensor = torch.stack([x1, y1, x2, y2], dim=1).to(torch.int)
    img_uint8 = (image_tensor * 255).byte().cpu()
    drawn = draw_bounding_boxes(img_uint8, boxes_tensor, labels=labels, colors=colors, width=2)
    return T.ToPILImage()(drawn)

# --- EXECUTION ---
results = []
sample_frames = []
total_tp = total_fp = total_fn = 0

seq_dirs = []
for split in ["train", "test"]:
    split_dir = os.path.join(BASE_DATA_ROOT, split)
    if not os.path.exists(split_dir):
        continue
    for d in sorted(os.listdir(split_dir)):
        full_path = os.path.join(split_dir, d)
        if os.path.isdir(full_path):
            seq_dirs.append((split, d))

print("Using device:", DEVICE)
print("Processing sequences...")

for split, seq_id in tqdm(seq_dirs, desc="Sequences", dynamic_ncols=True):
    seq_path = os.path.join(BASE_DATA_ROOT, split, seq_id)
    img_dir = os.path.join(seq_path, IMAGE_FOLDER)
    gt_path = os.path.join(seq_path, "gt", GT_FILENAME)
    gt_dict = load_gt_boxes(gt_path)

    if not os.path.exists(img_dir):
        continue

    all_img_paths = sorted([
        os.path.join(img_dir, file)
        for file in os.listdir(img_dir)
        if any(file.lower().endswith(ext) for ext in IMAGE_EXTS)
    ])

    random.shuffle(all_img_paths)
    all_img_paths = all_img_paths[:SAMPLE_PER_SEQ]

    for path in all_img_paths:
        try:
            img = Image.open(path).convert("RGB")
        except:
            continue

        img_tensor = transform(img).unsqueeze(0)
        img_tensor = img_tensor.half()
        img_tensor = img_tensor.squeeze(0) 

        img_tensor = img_tensor.to(DEVICE)



        filename = os.path.basename(path)
        try:
            frame_id = int(filename.split('.')[0])
        except:
            continue

        gt_boxes = gt_dict.get(frame_id, [])

        with torch.no_grad():
            yolo_result = model(img)[0]  # Get first result
            preds = yolo_result.boxes.data.to(DEVICE) if yolo_result.boxes is not None else torch.empty((0, 6)).to(DEVICE)

        pred_boxes = preds[:, :4][preds[:, 4] > SCORE_THRESH] if len(preds) else torch.empty((0, 4), device=DEVICE)

        # Accuracy
        if gt_boxes:
            gt_tensor = torch.stack(gt_boxes).to(DEVICE)
            if len(pred_boxes) > 0:
                ious = compute_iou(pred_boxes, gt_tensor)
                max_ious = ious.max(dim=1)[0]
                acc = (max_ious > IOU_THRESH).float().mean().item()
            else:
                acc = 0.0
        else:
            acc = 1.0 if len(pred_boxes) == 0 else 0.0

        results.append(acc)

        # Precision/Recall
        matched_gt = set()
        tp = fp = 0
        if len(pred_boxes) > 0 and len(gt_boxes) > 0:
            ious = compute_iou(pred_boxes, gt_tensor)
            for i in range(len(pred_boxes)):
                max_iou, gt_idx = ious[i].max(0)
                if max_iou > IOU_THRESH and gt_idx.item() not in matched_gt:
                    tp += 1
                    matched_gt.add(gt_idx.item())
                else:
                    fp += 1
        else:
            tp = 0
            fp = len(pred_boxes)

        fn = len(gt_boxes) - len(matched_gt)
        total_tp += tp
        total_fp += fp
        total_fn += fn

        if len(sample_frames) < NUM_VISUALS and seq_id not in [s[0] for s in sample_frames]:
            img_vis = plot_gt_and_detections(img_tensor, pred_boxes, gt_boxes)
            sample_frames.append((seq_id, filename, img_vis))
            

# --- METRICS ---
precision = total_tp / (total_tp + total_fp + 1e-6)
recall = total_tp / (total_tp + total_fn + 1e-6)
avg_acc = sum(results) / len(results) if results else 0
print(f"\nAverage Detection Accuracy over {len(results)} frames: {avg_acc * 100:.2f}%")
print(f"Precision: {precision:.3f}, Recall: {recall:.3f}")

# --- SHOW EXAMPLES ---
for seq_id, filename, img in sample_frames:
    plt.imshow(img)
    plt.title(f"Sequence {seq_id}, Frame {filename}\nRed = Prediction, Green = Ground Truth")
    plt.axis("off")
    plt.show()
# Out:
# Using device: mps
# Processing sequences...
# Sequences:   0%|          | 0/106 [00:00<?, ?it/s]
# 0: 384x640 14 persons, 47.5ms
# Speed: 2.6ms preprocess, 47.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.4ms
# Speed: 1.4ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 37.7ms
# Speed: 1.7ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.1ms
# Speed: 1.4ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 39.8ms
# Speed: 1.3ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 38.0ms
# Speed: 1.6ms preprocess, 38.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.4ms
# Speed: 1.9ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.5ms
# Speed: 1.7ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 sports ball, 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 64.5ms
# Speed: 1.5ms preprocess, 64.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.2ms
# Speed: 1.5ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   1%|          | 1/106 [00:11<19:16, 11.01s/it]
# 0: 384x640 23 persons, 43.7ms
# Speed: 1.7ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 43.2ms
# Speed: 1.9ms preprocess, 43.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 47.5ms
# Speed: 1.4ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.0ms
# Speed: 1.5ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 36.0ms
# Speed: 1.8ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.8ms
# Speed: 1.6ms preprocess, 39.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 69.0ms
# Speed: 1.5ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 38.0ms
# Speed: 1.4ms preprocess, 38.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 41.6ms
# Speed: 2.4ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 294.5ms
# Speed: 1.4ms preprocess, 294.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 46.1ms
# Speed: 1.9ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   2%|▏         | 2/106 [00:16<13:50,  7.99s/it]
# 0: 384x640 23 persons, 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 38.8ms
# Speed: 1.8ms preprocess, 38.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 41.0ms
# Speed: 1.9ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.0ms
# Speed: 2.2ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.9ms
# Speed: 2.3ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 37.8ms
# Speed: 1.8ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.6ms
# Speed: 1.5ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 sports ball, 35.1ms
# Speed: 1.7ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 43.5ms
# Speed: 1.7ms preprocess, 43.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 41.5ms
# Speed: 2.1ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 sports ball, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 39.7ms
# Speed: 1.8ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 38.3ms
# Speed: 1.7ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.6ms
# Speed: 2.3ms preprocess, 41.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 39.3ms
# Speed: 3.1ms preprocess, 39.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 58.1ms
# Speed: 7.7ms preprocess, 58.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 sports ball, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 41.8ms
# Speed: 1.9ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 42.3ms
# Speed: 2.2ms preprocess, 42.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   3%|▎         | 3/106 [00:23<12:16,  7.15s/it]
# 0: 384x640 15 persons, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.5ms
# Speed: 1.3ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.3ms
# Speed: 2.1ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.9ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 80.2ms
# Speed: 1.3ms preprocess, 80.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 42.7ms
# Speed: 1.7ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 39.7ms
# Speed: 1.8ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 39.1ms
# Speed: 1.7ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 39.6ms
# Speed: 1.6ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 44.4ms
# Speed: 1.4ms preprocess, 44.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 40.6ms
# Speed: 1.9ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   4%|▍         | 4/106 [00:28<11:14,  6.61s/it]
# 0: 384x640 19 persons, 125.9ms
# Speed: 1.6ms preprocess, 125.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.2ms
# Speed: 1.6ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.7ms
# Speed: 1.3ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.6ms
# Speed: 2.0ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 71.5ms
# Speed: 1.6ms preprocess, 71.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 34.8ms
# Speed: 1.5ms preprocess, 34.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.2ms
# Speed: 2.1ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.9ms
# Speed: 1.6ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 37.8ms
# Speed: 1.8ms preprocess, 37.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 33.1ms
# Speed: 1.6ms preprocess, 33.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.4ms
# Speed: 1.6ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.7ms
# Speed: 2.1ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.4ms
# Speed: 1.6ms preprocess, 38.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.7ms
# Speed: 1.7ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 59.5ms
# Speed: 2.9ms preprocess, 59.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 36.4ms
# Speed: 1.4ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   5%|▍         | 5/106 [00:35<11:17,  6.71s/it]
# 0: 384x640 14 persons, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 73.8ms
# Speed: 1.6ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.6ms
# Speed: 3.1ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.5ms
# Speed: 1.4ms preprocess, 38.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.6ms
# Speed: 2.2ms preprocess, 38.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 38.2ms
# Speed: 1.6ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.4ms
# Speed: 1.6ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 36.4ms
# Speed: 1.5ms preprocess, 36.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 36.4ms
# Speed: 1.4ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 127.1ms
# Speed: 1.8ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 37.8ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.7ms
# Speed: 2.2ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   6%|▌         | 6/106 [00:41<10:56,  6.56s/it]
# 0: 384x640 20 persons, 86.6ms
# Speed: 1.4ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.4ms
# Speed: 1.8ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 36.4ms
# Speed: 1.3ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 37.0ms
# Speed: 1.5ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.7ms
# Speed: 1.8ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.4ms
# Speed: 1.9ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 40.6ms
# Speed: 1.5ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.0ms
# Speed: 2.1ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 37.5ms
# Speed: 1.6ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 34.8ms
# Speed: 1.3ms preprocess, 34.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 34.6ms
# Speed: 2.1ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 39.4ms
# Speed: 6.3ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 38.2ms
# Speed: 1.9ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.4ms
# Speed: 1.6ms preprocess, 59.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 36.3ms
# Speed: 1.4ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   7%|▋         | 7/106 [00:48<10:49,  6.56s/it]
# 0: 384x640 25 persons, 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 36.5ms
# Speed: 1.3ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 36.4ms
# Speed: 1.8ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 65.7ms
# Speed: 10.5ms preprocess, 65.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 39.8ms
# Speed: 1.9ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 37.9ms
# Speed: 1.3ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 sports ball, 35.9ms
# Speed: 1.6ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 36.7ms
# Speed: 1.3ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 37.9ms
# Speed: 1.4ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.7ms
# Speed: 1.5ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 34.4ms
# Speed: 1.4ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 35.5ms
# Speed: 1.6ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 35.2ms
# Speed: 1.7ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 35.6ms
# Speed: 1.9ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 42.4ms
# Speed: 2.2ms preprocess, 42.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 37.2ms
# Speed: 1.3ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 36.7ms
# Speed: 1.8ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 38.4ms
# Speed: 1.6ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   8%|▊         | 8/106 [00:54<10:26,  6.39s/it]
# 0: 384x640 13 persons, 1 sports ball, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.1ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.6ms
# Speed: 1.2ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 61.7ms
# Speed: 1.6ms preprocess, 61.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 38.5ms
# Speed: 1.4ms preprocess, 38.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 36.1ms
# Speed: 1.2ms preprocess, 36.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.9ms
# Speed: 1.9ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 sports ball, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 36.5ms
# Speed: 1.6ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 37.7ms
# Speed: 4.3ms preprocess, 37.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.0ms
# Speed: 1.6ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 36.8ms
# Speed: 1.6ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 39.4ms
# Speed: 1.4ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.7ms
# Speed: 1.8ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 sports ball, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 37.7ms
# Speed: 1.4ms preprocess, 37.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 37.9ms
# Speed: 1.4ms preprocess, 37.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.2ms
# Speed: 1.6ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   8%|▊         | 9/106 [01:00<10:02,  6.21s/it]
# 0: 384x640 14 persons, 39.4ms
# Speed: 1.8ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 40.3ms
# Speed: 2.8ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.9ms
# Speed: 1.4ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 36.9ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 35.1ms
# Speed: 1.9ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 34.2ms
# Speed: 1.6ms preprocess, 34.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.2ms
# Speed: 1.6ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.5ms
# Speed: 1.4ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.6ms
# Speed: 1.4ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.8ms
# Speed: 1.7ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.4ms
# Speed: 1.5ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.8ms
# Speed: 1.5ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 34.8ms
# Speed: 1.9ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.8ms
# Speed: 1.7ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 85.2ms
# Speed: 4.4ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   9%|▉         | 10/106 [01:06<09:41,  6.06s/it]
# 0: 384x640 13 persons, 35.9ms
# Speed: 1.3ms preprocess, 35.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 53.7ms
# Speed: 2.3ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 36.6ms
# Speed: 1.3ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 38.2ms
# Speed: 1.9ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 34.3ms
# Speed: 1.9ms preprocess, 34.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 34.4ms
# Speed: 1.4ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 60.9ms
# Speed: 2.2ms preprocess, 60.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 39.4ms
# Speed: 1.5ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 44.2ms
# Speed: 2.6ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 37.3ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 44.6ms
# Speed: 1.5ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 44.0ms
# Speed: 2.5ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  10%|█         | 11/106 [01:11<09:03,  5.72s/it]
# 0: 384x640 13 persons, 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 37.4ms
# Speed: 1.8ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.1ms
# Speed: 1.9ms preprocess, 36.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 77.1ms
# Speed: 1.9ms preprocess, 77.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.4ms
# Speed: 1.3ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 37.2ms
# Speed: 1.8ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 36.4ms
# Speed: 1.3ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 37.0ms
# Speed: 1.3ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.4ms
# Speed: 1.3ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 36.6ms
# Speed: 1.5ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.1ms
# Speed: 1.8ms preprocess, 36.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 57.3ms
# Speed: 1.8ms preprocess, 57.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 35.4ms
# Speed: 1.9ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 36.6ms
# Speed: 1.4ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.5ms
# Speed: 1.6ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 35.9ms
# Speed: 1.8ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  11%|█▏        | 12/106 [01:16<08:59,  5.74s/it]
# 0: 384x640 13 persons, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.3ms
# Speed: 1.6ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 9 persons, 38.7ms
# Speed: 2.0ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  96%|█████████▌| 102/106 [08:51<00:20,  5.02s/it]
# 0: 384x640 20 persons, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 39.1ms
# Speed: 1.3ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 38.8ms
# Speed: 1.8ms preprocess, 38.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 39.4ms
# Speed: 1.9ms preprocess, 39.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.3ms
# Speed: 1.2ms preprocess, 39.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.1ms
# Speed: 1.5ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.7ms
# Speed: 1.5ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 32.7ms
# Speed: 1.4ms preprocess, 32.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.1ms
# Speed: 1.4ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 32.6ms
# Speed: 1.4ms preprocess, 32.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 33.9ms
# Speed: 1.3ms preprocess, 33.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 33.8ms
# Speed: 1.6ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 73.8ms
# Speed: 9.3ms preprocess, 73.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.0ms
# Speed: 1.2ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  97%|█████████▋| 103/106 [08:56<00:15,  5.11s/it]
# 0: 384x640 17 persons, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.6ms
# Speed: 1.3ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 37.2ms
# Speed: 2.4ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 37.8ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.1ms
# Speed: 1.3ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.5ms
# Speed: 2.3ms preprocess, 37.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.1ms
# Speed: 2.0ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.9ms
# Speed: 1.6ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 37.8ms
# Speed: 1.9ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.5ms
# Speed: 1.6ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 38.5ms
# Speed: 1.2ms preprocess, 38.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.9ms
# Speed: 1.6ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.1ms
# Speed: 1.7ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 33.3ms
# Speed: 1.2ms preprocess, 33.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  98%|█████████▊| 104/106 [09:02<00:10,  5.17s/it]
# 0: 384x640 21 persons, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 58.8ms
# Speed: 1.6ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 36.8ms
# Speed: 1.7ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 35.5ms
# Speed: 1.6ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 33.0ms
# Speed: 1.3ms preprocess, 33.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 33.0ms
# Speed: 1.2ms preprocess, 33.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 34.8ms
# Speed: 1.8ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.7ms
# Speed: 1.3ms preprocess, 34.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.4ms
# Speed: 1.4ms preprocess, 36.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 32.7ms
# Speed: 1.4ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 34.5ms
# Speed: 1.3ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  99%|█████████▉| 105/106 [09:07<00:05,  5.16s/it]
# 0: 384x640 14 persons, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.7ms
# Speed: 1.3ms preprocess, 58.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.8ms
# Speed: 2.0ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.0ms
# Speed: 1.3ms preprocess, 39.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.2ms
# Speed: 1.5ms preprocess, 39.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 71.6ms
# Speed: 17.5ms preprocess, 71.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.1ms
# Speed: 1.3ms preprocess, 39.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.9ms
# Speed: 1.3ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 34.9ms
# Speed: 1.4ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.4ms
# Speed: 1.7ms preprocess, 34.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 34.4ms
# Speed: 1.6ms preprocess, 34.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 baseball bat, 35.0ms
# Speed: 1.8ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 33.2ms
# Speed: 1.3ms preprocess, 33.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 34.7ms
# Speed: 1.5ms preprocess, 34.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 37.4ms
# Speed: 1.4ms preprocess, 37.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 32.6ms
# Speed: 1.4ms preprocess, 32.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 34.9ms
# Speed: 1.7ms preprocess, 34.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 35.9ms
# Speed: 1.7ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences: 100%|██████████| 106/106 [09:12<00:00,  5.21s/it]
# Average Detection Accuracy over 3180 frames: 93.08%
# Precision: 0.929, Recall: 0.570
