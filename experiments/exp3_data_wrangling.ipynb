# %% [markdown]
# # Experiment 3: Data Wrangling
#
# The next step to building Faster RCNN would be an intersection of union implementation to compare proposed bounding boxes to the ground truth.
#
# However, the current layout of the dataset does not make this easy, as this dataset was originally created for tracking. So each data "point" is a sequence, where the sequence consists of 600+ frames.
#
# The ground truth bounding boxes for every frame of each sequence are located in a single file: soccernet_data/tracking/train/SNMOT-XXX/gt/gt.txt, in the following format (we don't need the last 3 entries):
#
# `[frame ID, track ID, top left coordinate of the bounding box, top y coordinate, width, height, confidence score for the detection (1 for ground truth), -1, -1, -1 ]`
#
# The frames for each sequence "XXX" are located in  soccernet_data/tracking/train/SNMOT-XXX/img1/
#
# The data structure looks like this:
#
#  ```
#  soccernet_data/
#  └─ tracking/
#     └─ train/
#        ├─ SNMOT-060/
#        │  ├─ seqinfo.ini       # sequence metadata
#        │  ├─ gameinfo.ini      # game metadata
#        │  ├─ img1/             # all image frames
#        │  ├─ gt/               # ground‐truth annotations
#        │  ├─ det/              # detection results
#        ├─ …
#        ├─ SNMOT-XXX/           # …
#        │  └─ (same as above)
#        ├─ …
#        └─ SNMOT-170/
#           ├─ seqinfo.ini
#           ├─ gameinfo.ini
#           ├─ img1/
#           ├─ gt/
#           ├─ det/
#  ```
#
# So, we need to:
# 1. load frames for a specified sequence
# 2. match each of the images with their respective bounding boxes in gt.txt, keeping only the necessary values
# 3. transform the ground truth bounding boxes to match the format from experiment 2: [ymin, xmin, ymax, xmax]

# %%
import os
import numpy as np

"""
Let's make a soccernet_data/tracking/train/SNMOT-XXX/gt-frame/ directory where each frame has a txt file:
i.e. 
soccernet_data/tracking/train/SNMOT-XXX/gt-frame/000001.txt
= track ID, ymin, xmin, ymax, xmax
"""

def generate_per_frame_gt_files(sequence_id):
    base_dir   = os.path.join("..", "soccernet_data", "tracking", "train", sequence_id)
    gt_txt     = os.path.join(base_dir, "gt", "gt.txt")
    output_dir = os.path.join(base_dir, "gt-frame")

    os.makedirs(output_dir, exist_ok=True)

    gt_data = np.loadtxt(gt_txt, delimiter=",")
    for frame_id in sorted(set(gt_data[:, 0].astype(int))):
        rows = gt_data[gt_data[:, 0] == frame_id]
        frame_name = f"{frame_id:06d}.txt"
        out_path = os.path.join(output_dir, frame_name)
        with open(out_path, "w") as fout:
            for row in rows:
                _, track_id, x, y, w, h, *_ = row
                xmin, ymin = x, y
                xmax, ymax = x + w, y + h
                fout.write(f"{int(track_id)},{int(ymin)},{int(xmin)},{int(ymax)},{int(xmax)}\n")

    print(f"Generated per-frame ground truth files in: {output_dir}")

# %%
# Verifying the output
generate_per_frame_gt_files("SNMOT-060")
# Out:
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-060/gt-frame

# %%
train_root = os.path.join("..", "soccernet_data", "tracking", "train")


sequence_ids = [
    d for d in os.listdir(train_root)
    if os.path.isdir(os.path.join(train_root, d))
]

for seq in sorted(sequence_ids):
    print(f"Processing sequence {seq}...")
    generate_per_frame_gt_files(seq)
# Out:
# Processing sequence SNMOT-060...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-060/gt-frame
# Processing sequence SNMOT-061...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-061/gt-frame
# Processing sequence SNMOT-062...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-062/gt-frame
# Processing sequence SNMOT-063...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-063/gt-frame
# Processing sequence SNMOT-064...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-064/gt-frame
# Processing sequence SNMOT-065...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-065/gt-frame
# Processing sequence SNMOT-066...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-066/gt-frame
# Processing sequence SNMOT-067...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-067/gt-frame
# Processing sequence SNMOT-068...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-068/gt-frame
# Processing sequence SNMOT-069...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-069/gt-frame
# Processing sequence SNMOT-070...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-070/gt-frame
# Processing sequence SNMOT-071...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-071/gt-frame
# Processing sequence SNMOT-072...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-072/gt-frame
# Processing sequence SNMOT-073...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-073/gt-frame
# Processing sequence SNMOT-074...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-074/gt-frame
# Processing sequence SNMOT-075...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-075/gt-frame
# Processing sequence SNMOT-076...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-076/gt-frame
# Processing sequence SNMOT-077...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-077/gt-frame
# Processing sequence SNMOT-097...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-097/gt-frame
# Processing sequence SNMOT-098...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-098/gt-frame
# Processing sequence SNMOT-099...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-099/gt-frame
# Processing sequence SNMOT-100...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-100/gt-frame
# Processing sequence SNMOT-101...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-101/gt-frame
# Processing sequence SNMOT-102...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-102/gt-frame
# Processing sequence SNMOT-103...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-103/gt-frame
# Processing sequence SNMOT-104...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-104/gt-frame
# Processing sequence SNMOT-105...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-105/gt-frame
# Processing sequence SNMOT-106...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-106/gt-frame
# Processing sequence SNMOT-107...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-107/gt-frame
# Processing sequence SNMOT-108...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-108/gt-frame
# Processing sequence SNMOT-109...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-109/gt-frame
# Processing sequence SNMOT-110...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-110/gt-frame
# Processing sequence SNMOT-111...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-111/gt-frame
# Processing sequence SNMOT-112...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-112/gt-frame
# Processing sequence SNMOT-113...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-113/gt-frame
# Processing sequence SNMOT-114...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-114/gt-frame
# Processing sequence SNMOT-115...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-115/gt-frame
# Processing sequence SNMOT-151...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-151/gt-frame
# Processing sequence SNMOT-152...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-152/gt-frame
# Processing sequence SNMOT-153...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-153/gt-frame
# Processing sequence SNMOT-154...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-154/gt-frame
# Processing sequence SNMOT-155...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-155/gt-frame
# Processing sequence SNMOT-156...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-156/gt-frame
# Processing sequence SNMOT-157...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-157/gt-frame
# Processing sequence SNMOT-158...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-158/gt-frame
# Processing sequence SNMOT-159...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-159/gt-frame
# Processing sequence SNMOT-160...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-160/gt-frame
# Processing sequence SNMOT-161...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-161/gt-frame
# Processing sequence SNMOT-162...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-162/gt-frame
# Processing sequence SNMOT-163...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-163/gt-frame
# Processing sequence SNMOT-164...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-164/gt-frame
# Processing sequence SNMOT-165...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-165/gt-frame
# Processing sequence SNMOT-166...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-166/gt-frame
# Processing sequence SNMOT-167...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-167/gt-frame
# Processing sequence SNMOT-168...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-168/gt-frame
# Processing sequence SNMOT-169...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-169/gt-frame
# Processing sequence SNMOT-170...
# Generated per-frame ground truth files in: ../soccernet_data/tracking/train/SNMOT-170/gt-frame
