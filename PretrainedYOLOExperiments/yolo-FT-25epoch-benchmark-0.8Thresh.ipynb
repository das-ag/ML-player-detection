# %%
import os
import torch
import torchvision.transforms as T
import matplotlib.pyplot as plt
from collections import defaultdict
from PIL import Image
from tqdm import tqdm
from ultralytics import YOLO  # Ensure you have `pip install ultralytics`
import random


# --- CONFIG ---
# DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {DEVICE}") 
BASE_DATA_ROOT = "../soccernet_data/tracking"
GT_FILENAME = "gt.txt"
IMAGE_FOLDER = "img1"
IMAGE_EXTS = ['.jpg', '.png']
NUM_VISUALS = 10
SCORE_THRESH = 0.8
IOU_THRESH = 0.5
SAMPLE_PER_SEQ = 30
# Out:
# Using device: mps

# %%
# --- LOAD MODEL ---
model = YOLO("discovery-runs/detect/ft-25epoch/weights/best.pt").to(DEVICE)
# model.half().to(DEVICE)
# model.to(DEVICE)

transform = T.ToTensor()

def load_gt_boxes(gt_path):
    gt_dict = defaultdict(list)
    if not os.path.exists(gt_path):
        return gt_dict
    with open(gt_path, 'r') as f:
        for line in f:
            parts = line.strip().split(',')
            frame, _, x, y, w, h, cls, _, _ = map(int, parts[:9])
            gt_dict[frame].append(torch.tensor([x, y, x + w, y + h], device=DEVICE))
    return gt_dict

def compute_iou(box1, box2):
    if box1.size(0) == 0 or box2.size(0) == 0:
        return torch.zeros((box1.size(0), box2.size(0)), device=box1.device)
    area1 = (box1[:, 2] - box1[:, 0]) * (box1[:, 3] - box1[:, 1])
    area2 = (box2[:, 2] - box2[:, 0]) * (box2[:, 3] - box2[:, 1])
    lt = torch.max(box1[:, None, :2], box2[:, :2])
    rb = torch.min(box1[:, None, 2:], box2[:, 2:])
    wh = (rb - lt).clamp(min=0)
    inter = wh[:, :, 0] * wh[:, :, 1]
    union = area1[:, None] + area2 - inter
    iou = inter / union
    return iou

def plot_gt_and_detections(image_tensor, detections, gt_boxes):
    from torchvision.utils import draw_bounding_boxes
    all_boxes = []
    labels = []
    colors = []

    for box in detections:
        all_boxes.append(box)
        labels.append("pred")
        colors.append("red")

    for box in gt_boxes:
        all_boxes.append(box)
        labels.append("gt")
        colors.append("green")

    if not all_boxes:
        return T.ToPILImage()(image_tensor)
    
    boxes_tensor = torch.stack(all_boxes).cpu()

    
    x1 = torch.min(boxes_tensor[:, 0], boxes_tensor[:, 2])
    y1 = torch.min(boxes_tensor[:, 1], boxes_tensor[:, 3])
    x2 = torch.max(boxes_tensor[:, 0], boxes_tensor[:, 2])
    y2 = torch.max(boxes_tensor[:, 1], boxes_tensor[:, 3])
    boxes_tensor = torch.stack([x1, y1, x2, y2], dim=1).to(torch.int)
    img_uint8 = (image_tensor * 255).byte().cpu()
    drawn = draw_bounding_boxes(img_uint8, boxes_tensor, labels=labels, colors=colors, width=2)
    return T.ToPILImage()(drawn)

# --- EXECUTION ---
results = []
sample_frames = []
total_tp = total_fp = total_fn = 0

seq_dirs = []
for split in ["train", "test"]:
    split_dir = os.path.join(BASE_DATA_ROOT, split)
    if not os.path.exists(split_dir):
        continue
    for d in sorted(os.listdir(split_dir)):
        full_path = os.path.join(split_dir, d)
        if os.path.isdir(full_path):
            seq_dirs.append((split, d))

print("Using device:", DEVICE)
print("Processing sequences...")

for split, seq_id in tqdm(seq_dirs, desc="Sequences", dynamic_ncols=True):
    seq_path = os.path.join(BASE_DATA_ROOT, split, seq_id)
    img_dir = os.path.join(seq_path, IMAGE_FOLDER)
    gt_path = os.path.join(seq_path, "gt", GT_FILENAME)
    gt_dict = load_gt_boxes(gt_path)

    if not os.path.exists(img_dir):
        continue

    all_img_paths = sorted([
        os.path.join(img_dir, file)
        for file in os.listdir(img_dir)
        if any(file.lower().endswith(ext) for ext in IMAGE_EXTS)
    ])

    random.shuffle(all_img_paths)
    all_img_paths = all_img_paths[:SAMPLE_PER_SEQ]

    for path in all_img_paths:
        try:
            img = Image.open(path).convert("RGB")
        except:
            continue

        img_tensor = transform(img).unsqueeze(0)
        img_tensor = img_tensor.half()
        img_tensor = img_tensor.squeeze(0) 

        img_tensor = img_tensor.to(DEVICE)



        filename = os.path.basename(path)
        try:
            frame_id = int(filename.split('.')[0])
        except:
            continue

        gt_boxes = gt_dict.get(frame_id, [])

        with torch.no_grad():
            yolo_result = model(img)[0]  # Get first result
            preds = yolo_result.boxes.data.to(DEVICE) if yolo_result.boxes is not None else torch.empty((0, 6)).to(DEVICE)

        pred_boxes = preds[:, :4][preds[:, 4] > SCORE_THRESH] if len(preds) else torch.empty((0, 4), device=DEVICE)

        # Accuracy
        if gt_boxes:
            gt_tensor = torch.stack(gt_boxes).to(DEVICE)
            if len(pred_boxes) > 0:
                ious = compute_iou(pred_boxes, gt_tensor)
                max_ious = ious.max(dim=1)[0]
                acc = (max_ious > IOU_THRESH).float().mean().item()
            else:
                acc = 0.0
        else:
            acc = 1.0 if len(pred_boxes) == 0 else 0.0

        results.append(acc)

        # Precision/Recall
        matched_gt = set()
        tp = fp = 0
        if len(pred_boxes) > 0 and len(gt_boxes) > 0:
            ious = compute_iou(pred_boxes, gt_tensor)
            for i in range(len(pred_boxes)):
                max_iou, gt_idx = ious[i].max(0)
                if max_iou > IOU_THRESH and gt_idx.item() not in matched_gt:
                    tp += 1
                    matched_gt.add(gt_idx.item())
                else:
                    fp += 1
        else:
            tp = 0
            fp = len(pred_boxes)

        fn = len(gt_boxes) - len(matched_gt)
        total_tp += tp
        total_fp += fp
        total_fn += fn

        if len(sample_frames) < NUM_VISUALS and seq_id not in [s[0] for s in sample_frames]:
            img_vis = plot_gt_and_detections(img_tensor, pred_boxes, gt_boxes)
            sample_frames.append((seq_id, filename, img_vis))
            

# --- METRICS ---
precision = total_tp / (total_tp + total_fp + 1e-6)
recall = total_tp / (total_tp + total_fn + 1e-6)
avg_acc = sum(results) / len(results) if results else 0
print(f"\nAverage Detection Accuracy over {len(results)} frames: {avg_acc * 100:.2f}%")
print(f"Precision: {precision:.3f}, Recall: {recall:.3f}")

# --- SHOW EXAMPLES ---
for seq_id, filename, img in sample_frames:
    plt.imshow(img)
    plt.title(f"Sequence {seq_id}, Frame {filename}\nRed = Prediction, Green = Ground Truth")
    plt.axis("off")
    plt.show()
# Out:
# Using device: mps
# Processing sequences...
# Sequences:   0%|          | 0/106 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 2.050s exceeded
# 0: 384x640 20 players, 2 referees, 451.6ms
# Speed: 72.1ms preprocess, 451.6ms inference, 5076.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 18.1ms
# Speed: 2.5ms preprocess, 18.1ms inference, 480.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2 referees, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 957.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 16.2ms
# Speed: 2.8ms preprocess, 16.2ms inference, 62.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 16.9ms
# Speed: 2.6ms preprocess, 16.9ms inference, 92.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 55.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 15.7ms
# Speed: 2.5ms preprocess, 15.7ms inference, 55.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 45.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 58.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 89.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 68.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 19.1ms
# Speed: 8.3ms preprocess, 19.1ms inference, 44.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 1 referee, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 95.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 57.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 41.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 14 players, 1 referee, 15.1ms
# Speed: 2.6ms preprocess, 15.1ms inference, 43.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 47.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 46.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 49.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 19.0ms
# Speed: 2.5ms preprocess, 19.0ms inference, 48.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 15.3ms
# Speed: 2.5ms preprocess, 15.3ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 43.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 43.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2 referees, 15.1ms
# Speed: 2.6ms preprocess, 15.1ms inference, 42.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2 referees, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 41.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 1 referee, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 56.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 16 players, 1 referee, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1 referee, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 43.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 15.2ms
# Speed: 2.5ms preprocess, 15.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   1%|          | 1/106 [00:23<41:24, 23.66s/it]
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 48.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 49.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 46.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 30.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 474.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 45.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 47.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 16.9ms
# Speed: 2.6ms preprocess, 16.9ms inference, 49.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 players, 17.8ms
# Speed: 2.1ms preprocess, 17.8ms inference, 64.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 53.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 70.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 53.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 16 players, 1 referee, 16.4ms
# Speed: 2.7ms preprocess, 16.4ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 55.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 54.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 players, 2 referees, 22.1ms
# Speed: 2.1ms preprocess, 22.1ms inference, 73.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 42.2ms
# Speed: 3.0ms preprocess, 42.2ms inference, 81.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2 referees, 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 25.7ms
# Speed: 2.3ms preprocess, 25.7ms inference, 26.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1 referee, 15.4ms
# Speed: 2.5ms preprocess, 15.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 17.7ms
# Speed: 3.9ms preprocess, 17.7ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 76.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 players, 1 referee, 21.9ms
# Speed: 2.1ms preprocess, 21.9ms inference, 117.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 41.0ms
# Speed: 2.3ms preprocess, 41.0ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 55.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 53.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 3 referees, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   2%|▏         | 2/106 [00:31<25:11, 14.54s/it]
# 0: 384x640 15 players, 37.4ms
# Speed: 2.6ms preprocess, 37.4ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 16.2ms
# Speed: 2.7ms preprocess, 16.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 53.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 21.0ms
# Speed: 3.8ms preprocess, 21.0ms inference, 54.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 70.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 18.0ms
# Speed: 3.8ms preprocess, 18.0ms inference, 54.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 55.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 19.9ms
# Speed: 2.6ms preprocess, 19.9ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 17.3ms
# Speed: 2.4ms preprocess, 17.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 55.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 28.8ms
# Speed: 4.5ms preprocess, 28.8ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 51.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 51.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 15.8ms
# Speed: 2.5ms preprocess, 15.8ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 18.3ms
# Speed: 3.0ms preprocess, 18.3ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 62.7ms
# Speed: 2.8ms preprocess, 62.7ms inference, 59.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 17.5ms
# Speed: 2.6ms preprocess, 17.5ms inference, 56.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 18.1ms
# Speed: 2.8ms preprocess, 18.1ms inference, 57.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 16.6ms
# Speed: 2.9ms preprocess, 16.6ms inference, 57.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 16.1ms
# Speed: 2.5ms preprocess, 16.1ms inference, 60.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 16.8ms
# Speed: 2.5ms preprocess, 16.8ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 16.4ms
# Speed: 2.4ms preprocess, 16.4ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 53.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   3%|▎         | 3/106 [00:39<19:28, 11.35s/it]
# 0: 384x640 15 players, 1 referee, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 18.5ms
# Speed: 2.3ms preprocess, 18.5ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1 referee, 15.6ms
# Speed: 2.9ms preprocess, 15.6ms inference, 53.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 19.1ms
# Speed: 2.5ms preprocess, 19.1ms inference, 79.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 61.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 18.3ms
# Speed: 1.9ms preprocess, 18.3ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 19.3ms
# Speed: 2.8ms preprocess, 19.3ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 18.6ms
# Speed: 6.8ms preprocess, 18.6ms inference, 57.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1 referee, 89.1ms
# Speed: 2.2ms preprocess, 89.1ms inference, 113.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1 referee, 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 69.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 51.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 53.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 51.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 51.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 51.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 49.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 15.2ms
# Speed: 2.6ms preprocess, 15.2ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 16.2ms
# Speed: 2.4ms preprocess, 16.2ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   4%|▍         | 4/106 [00:45<15:57,  9.39s/it]
# 0: 384x640 24 players, 1 referee, 32.8ms
# Speed: 2.6ms preprocess, 32.8ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 52.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 15.2ms
# Speed: 2.4ms preprocess, 15.2ms inference, 50.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 52.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 3 referees, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 55.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 2 referees, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 36.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 players, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 1 referee, 14.8ms
# Speed: 2.8ms preprocess, 14.8ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 72.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 2 referees, 16.5ms
# Speed: 2.7ms preprocess, 16.5ms inference, 54.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 players, 1 referee, 16.4ms
# Speed: 2.3ms preprocess, 16.4ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 52.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 24 players, 1 referee, 16.9ms
# Speed: 2.5ms preprocess, 16.9ms inference, 28.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 players, 2 referees, 16.3ms
# Speed: 2.5ms preprocess, 16.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 2 referees, 17.5ms
# Speed: 2.8ms preprocess, 17.5ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 52.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 51.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 15.1ms
# Speed: 2.8ms preprocess, 15.1ms inference, 52.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 1 referee, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 3 referees, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 23 players, 1 referee, 15.1ms
# Speed: 2.3ms preprocess, 15.1ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 51.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 3 referees, 15.1ms
# Speed: 2.3ms preprocess, 15.1ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 1 referee, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   5%|▍         | 5/106 [00:52<14:29,  8.61s/it]
# 0: 384x640 24 players, 1 referee, 34.6ms
# Speed: 2.2ms preprocess, 34.6ms inference, 62.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 2 referees, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 55.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 55.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 54.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 17.6ms
# Speed: 2.7ms preprocess, 17.6ms inference, 61.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 17.5ms
# Speed: 2.3ms preprocess, 17.5ms inference, 59.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 64.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 59.2ms
# Speed: 2.2ms preprocess, 59.2ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 61.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3 referees, 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 17.4ms
# Speed: 2.6ms preprocess, 17.4ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 17.3ms
# Speed: 2.5ms preprocess, 17.3ms inference, 62.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   6%|▌         | 6/106 [00:59<13:19,  7.99s/it]
# 0: 384x640 22 players, 1 referee, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 1 referee, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 16.8ms
# Speed: 2.4ms preprocess, 16.8ms inference, 69.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 players, 1 referee, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 46.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 2 referees, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 65.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 17.1ms
# Speed: 2.4ms preprocess, 17.1ms inference, 25.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 65.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 players, 3 referees, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 34.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 29 players, 2 referees, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 35.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 players, 1 referee, 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 64.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 15.4ms
# Speed: 2.5ms preprocess, 15.4ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 15.1ms
# Speed: 2.3ms preprocess, 15.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 2 referees, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 68.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 16.9ms
# Speed: 2.5ms preprocess, 16.9ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 32.4ms
# Speed: 9.1ms preprocess, 32.4ms inference, 74.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 33.8ms
# Speed: 2.2ms preprocess, 33.8ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 26 players, 1 referee, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   7%|▋         | 7/106 [01:07<12:54,  7.83s/it]
# 0: 384x640 21 players, 1 referee, 33.3ms
# Speed: 2.6ms preprocess, 33.3ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 67.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 players, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 35.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 68.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 64.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 70.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 players, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 72.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 32.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 19.0ms
# Speed: 2.6ms preprocess, 19.0ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 70.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 71.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 16.6ms
# Speed: 2.6ms preprocess, 16.6ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 2 referees, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 13 players, 2 referees, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 66.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 68.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 72.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 72.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   8%|▊         | 8/106 [01:14<12:24,  7.60s/it]
# 0: 384x640 1 goalkeeper, 18 players, 32.6ms
# Speed: 2.8ms preprocess, 32.6ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 73.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 31.2ms
# Speed: 8.1ms preprocess, 31.2ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 23 players, 1 referee, 16.9ms
# Speed: 2.3ms preprocess, 16.9ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 23 players, 1 referee, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1 referee, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 1 referee, 15.4ms
# Speed: 2.4ms preprocess, 15.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 63.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1 referee, 15.2ms
# Speed: 2.3ms preprocess, 15.2ms inference, 67.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 2 referees, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   8%|▊         | 9/106 [01:20<11:28,  7.09s/it]
# 0: 384x640 16 players, 3 referees, 33.3ms
# Speed: 2.2ms preprocess, 33.3ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 16.7ms
# Speed: 3.4ms preprocess, 16.7ms inference, 85.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 75.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 3 referees, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 3 referees, 16.7ms
# Speed: 1.8ms preprocess, 16.7ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 17.6ms
# Speed: 2.4ms preprocess, 17.6ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 71.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 16.9ms
# Speed: 2.4ms preprocess, 16.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 16.7ms
# Speed: 2.5ms preprocess, 16.7ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 17.3ms
# Speed: 2.4ms preprocess, 17.3ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 17.5ms
# Speed: 1.9ms preprocess, 17.5ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 17.5ms
# Speed: 2.6ms preprocess, 17.5ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 16.8ms
# Speed: 2.5ms preprocess, 16.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 1 referee, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:   9%|▉         | 10/106 [01:26<10:46,  6.74s/it]
# 0: 384x640 16 players, 33.1ms
# Speed: 2.2ms preprocess, 33.1ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 22.4ms
# Speed: 10.7ms preprocess, 22.4ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 71.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 15.5ms
# Speed: 2.7ms preprocess, 15.5ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 17.6ms
# Speed: 2.8ms preprocess, 17.6ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 23.4ms
# Speed: 2.4ms preprocess, 23.4ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 37.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 60.9ms
# Speed: 1.9ms preprocess, 60.9ms inference, 17.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  10%|█         | 11/106 [01:31<09:58,  6.29s/it]
# 0: 384x640 28 players, 32.8ms
# Speed: 2.3ms preprocess, 32.8ms inference, 73.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 players, 15.6ms
# Speed: 2.8ms preprocess, 15.6ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 players, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 players, 1 referee, 19.0ms
# Speed: 2.3ms preprocess, 19.0ms inference, 44.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 players, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 69.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 players, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 69.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 25 players, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 2 referees, 15.9ms
# ...
#
# 0: 384x640 20 players, 2 referees, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 17.5ms
# Speed: 2.3ms preprocess, 17.5ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1 referee, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 16.2ms
# Speed: 2.4ms preprocess, 16.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  97%|█████████▋| 103/106 [09:53<00:15,  5.25s/it]
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 14.9ms
# Speed: 1.8ms preprocess, 14.9ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 14.9ms
# Speed: 2.8ms preprocess, 14.9ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1 referee, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 2 referees, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 15.4ms
# Speed: 2.5ms preprocess, 15.4ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 15.2ms
# Speed: 2.4ms preprocess, 15.2ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  98%|█████████▊| 104/106 [09:59<00:10,  5.30s/it]
# 0: 384x640 26 players, 2 referees, 32.0ms
# Speed: 2.3ms preprocess, 32.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 24 players, 1 referee, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 32.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 players, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 14.0ms
# Speed: 2.7ms preprocess, 14.0ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 players, 15.3ms
# Speed: 2.6ms preprocess, 15.3ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1 referee, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 2 referees, 14.5ms
# Speed: 2.7ms preprocess, 14.5ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 1 referee, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 players, 18.3ms
# Speed: 2.3ms preprocess, 18.3ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 15.9ms
# Speed: 3.8ms preprocess, 15.9ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 1 referee, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 players, 15.2ms
# Speed: 2.6ms preprocess, 15.2ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
# Sequences:  99%|█████████▉| 105/106 [10:04<00:05,  5.26s/it]
# 0: 384x640 15 players, 1 referee, 31.4ms
# Speed: 2.6ms preprocess, 31.4ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 15.0ms
# Speed: 2.9ms preprocess, 15.0ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 14.9ms
# Speed: 2.8ms preprocess, 14.9ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 16.2ms
# Speed: 2.8ms preprocess, 16.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 14.7ms
# Speed: 2.4ms preprocess, 14.7ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 4 referees, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 3 referees, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
# Sequences: 100%|██████████| 106/106 [10:09<00:00,  5.75s/it]
# Average Detection Accuracy over 3180 frames: 94.06%
# Precision: 0.949, Recall: 0.543
